# %% [markdown]
# ### This notebook focus on combining MELT, SurVINDEL and MANTA matrix tables into a single final data release mt

# %%
# %%configure -f
# {"driverMemory": "6000M"}
# Out:
# Current session configs: <tt>{'driverMemory': '6000M', 'proxyUser': 'jovyan', 'kind': 'pyspark'}</tt><br>

# %%
import hail as hl
hl.init(sc)
# Out:
# Starting Spark application
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# pip-installed Hail requires additional configuration options in Spark referring
#   to the path to the Hail Python module directory HAIL_DIR,
#   e.g. /path/to/python/site-packages/hail:
#     spark.jars=HAIL_DIR/hail-all-spark.jar
#     spark.driver.extraClassPath=HAIL_DIR/hail-all-spark.jar
#     spark.executor.extraClassPath=./hail-all-spark.jarRunning on Apache Spark version 3.1.2-amzn-0
# SparkUI available at
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.80-4ccfae1ff293
# LOGGING: writing to

# %%
## list all resources  used in this notebook 

release14_melt_mt_uri =   "SG10K_SV_MELT.n5487.m24674.discovery.mt"
release14_manta_mt_uri =   "SG10K_SV_MantaSVimmerGraphtyper.n5487.m36145.discovery.DEL-INS-only.mt"
release14_survindel_mt_uri = "SG10K_SV_SURVINDEL2.n5487.m32465.discovery.mt"
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
manta_mt = hl.read_matrix_table(release14_manta_mt_uri)
melt_mt = hl.read_matrix_table(release14_melt_mt_uri)
surv_mt = hl.read_matrix_table(release14_survindel_mt_uri)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
def align_mt2_cols_to_mt1(mt1, mt2):
    mt1 = mt1.add_col_index()
    mt2 = mt2.add_col_index()
    new_col_order = mt2.index_cols(mt1.col_key).col_idx.collect()
    new_mt = mt2.choose_cols(new_col_order)
    new_mt = new_mt.drop('col_idx')
    return new_mt

manta_mt = manta_mt
melt_mt = align_mt2_cols_to_mt1(manta_mt, melt_mt).checkpoint("SG10K_SV_MELT.n5487.m24674.discovery.mt", overwrite=True)
surv_mt = align_mt2_cols_to_mt1(manta_mt, surv_mt).checkpoint("SG10K_SV_SURVINDEL2.n5487.m32465.discovery.mt", overwrite=True)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 2024-04-11 10:49:01 Hail: INFO: wrote matrix table with 24674 rows and 5487 columns in 16 partitions to SG10K_SV_MELT.n5487.m24674.discovery.mt
# 2024-04-11 10:49:28 Hail: INFO: wrote matrix table with 32465 rows and 5487 columns in 22 partitions to SG10K_SV_SURVINDEL2.n5487.m32465.discovery.mt

# %%
mt = manta_mt
mt = mt.annotate_entries(manta = hl.struct(), melt = hl.struct(), survindel2 = hl.struct())
mt = mt.transmute_entries(manta = mt.manta.annotate(**mt.entry), melt = hl.struct(), survindel2 = hl.struct())
mt = mt.annotate_entries(manta = mt.manta.drop('manta', 'melt', 'survindel2'))

mt = mt.annotate_rows(info = mt.info.annotate(alleles = mt.alleles, rsid = mt.rsid))
mt = mt.rename({'info':'info_manta'})
mt = mt.annotate_rows(info = hl.struct())
mt = mt.transmute_rows(info = mt.info.annotate(manta = mt.info_manta, melt = hl.struct(), survindel2 = hl.struct()))

manta_mt = mt
manta_mt.describe()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {
#             ABHet: float64,
#             ABHom: float64,
#             ABHetMulti: array<float64>,
#             ABHomMulti: array<float64>,
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             CR: int32,
#             END: int32,
#             HOMSEQ: array<str>,
#             INV3: bool,
#             INV5: bool,
#             LEFT_SVINSSEQ: array<str>,
#             LOGF: float64,
#             MaxAAS: array<int32>,
#             MaxAASR: array<float64>,
#             MaxAltPP: int32,
#             MQ: int32,
#             MQsquared: int32,
#             NCLUSTERS: int32,
#             NGT: array<int32>,
#             NHet: int32,
#             NHomRef: int32,
#             NHomAlt: int32,
#             NUM_MERGED_SVS: int32,
#             OLD_VARIANT_ID: str,
#             ORSTART: int32,
#             OREND: int32,
#             QD: float64,
#             PASS_AC: array<int32>,
#             PASS_AN: int32,
#             PASS_ratio: float64,
#             PS: int32,
#             RefLen: int32,
#             RELATED_SV_ID: int32,
#             RIGHT_SVINSSEQ: array<str>,
#             SB: float64,
#             SBAlt: float64,
#             SBF: array<int32>,
#             SBF1: array<int32>,
#             SBF2: array<int32>,
#             SBR: array<int32>,
#             SBR1: array<int32>,
#             SBR2: array<int32>,
#             SEQ: str,
#             SeqDepth: int32,
#             SV_ID: int32,
#             SVINSSEQ: array<str>,
#             SVLEN: int32,
#             SVMODEL: str,
#             SVSIZE: int32,
#             SVTYPE: str,
#             VarType: str,
#             PASS_GT2_filter: str,
#             alleles: array<str>,
#             rsid: str
#         },
#         melt: struct {},
#         survindel2: struct {}
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {
#         GT: call,
#         FT: str,
#         AD: array<int32>,
#         MD: int32,
#         DP: int32,
#         RA: array<int32>,
#         PP: int32,
#         GQ: int32,
#         PL: array<int32>
#     }
#     'melt': struct {}
#     'survindel2': struct {}
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %%
mt = melt_mt
mt = mt.annotate_entries(manta = hl.struct(), melt = hl.struct(), survindel2 = hl.struct())
mt = mt.transmute_entries(manta = hl.struct(), melt = mt.melt.annotate(**mt.entry), survindel2 = hl.struct())
mt = mt.annotate_entries(melt = mt.melt.drop('manta', 'melt', 'survindel2'))

mt = mt.annotate_rows(info = mt.info.annotate(alleles = mt.alleles, rsid = mt.rsid))
mt = mt.rename({'info':'info_melt'})
mt = mt.annotate_rows(info = hl.struct())
mt = mt.transmute_rows(info = mt.info.annotate(manta = hl.struct(), melt = mt.info_melt, survindel2 = hl.struct()))

melt_mt = mt
melt_mt.describe()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {},
#         melt: struct {
#             ASSESS: int32,
#             TSD: str,
#             INTERNAL: array<str>,
#             SVTYPE: str,
#             SVLEN: int32,
#             MEINFO: array<str>,
#             DIFF: array<str>,
#             LP: int32,
#             RP: int32,
#             RA: float64,
#             PRIOR: str,
#             SR: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         survindel2: struct {}
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {}
#     'melt': struct {
#         GT: call,
#         GL: array<float64>,
#         DP: int32,
#         AD: int32,
#         PL: array<int32>
#     }
#     'survindel2': struct {}
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %%
mt = surv_mt
mt = mt.annotate_entries(manta = hl.struct(), melt = hl.struct(), survindel2 = hl.struct())
mt = mt.transmute_entries(manta = hl.struct(), melt = hl.struct(), survindel2 = mt.survindel2.annotate(**mt.entry))
mt = mt.annotate_entries(survindel2 = mt.survindel2.drop('manta', 'melt', 'survindel2'))

mt = mt.annotate_rows(info = mt.info.annotate(alleles = mt.alleles, rsid = mt.rsid))
mt = mt.rename({'info':'info_survindel2'})
mt = mt.annotate_rows(info = hl.struct())
mt = mt.transmute_rows(info = mt.info.annotate(manta = hl.struct(), melt = hl.struct(),survindel2 = mt.info_survindel2))
mt = mt.drop('variant_qc','site_is_pass','n_called','n_hom_ref','n_het','n_hom_alt','n_non_ref')

surv_mt = mt
surv_mt.describe()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {},
#         melt: struct {},
#         survindel2: struct {
#             SVTYPE: str,
#             END: int32,
#             N_SAMPLES: int32,
#             N_SVS: int32,
#             GCF: float64,
#             SVSIZE: int32,
#             alleles: array<str>,
#             rsid: str
#         }
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {}
#     'melt': struct {}
#     'survindel2': struct {
#         GT: call,
#         FT: str,
#         AR: int32,
#         SR: int32,
#         RR: int32,
#         RS: int32,
#         RE: int32,
#         CN: int32,
#         IL: int32,
#         WR: int32,
#         DFL: int32,
#         DDL: int32,
#         DDR: int32,
#         DFR: int32,
#         CID: int32,
#         OW: int32,
#         DHFC: float64,
#         DHBFC: float64,
#         DHFFC: float64,
#         DHSP: int32,
#         FS: str
#     }
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %%
#mt = manta_mt 
surv_row_ht = surv_mt.rows()
melt_row_ht = melt_mt.rows()
manta_row_ht = manta_mt.rows()


manta_mt = manta_mt.transmute_rows(
    info = manta_mt.info.annotate(
            # manta = manta_row_ht[manta_mt.row_key].info.manta,
            melt = melt_row_ht[manta_mt.row_key].info.melt,
            survindel2 = surv_row_ht[manta_mt.row_key].info.survindel2,
    ))
#manta_mt.describe()
manta_mt = manta_mt.annotate_entries(    
    #manta = manta_mt[manta_mt.row_key, manta_mt.col_key].manta,
    melt = melt_mt[manta_mt.row_key, manta_mt.col_key].melt,
    survindel2 = surv_mt[manta_mt.row_key, manta_mt.col_key].survindel2, 
)
#manta_mt.describe()
manta_mt = manta_mt.checkpoint("SG10K_SV_MantaSVimmerGraphtyper.n5487.m36145.discovery.DEL-INS-only.complete_schema.mt", overwrite=True)
manta_mt.describe()



melt_mt = melt_mt.transmute_rows(
    info = melt_mt.info.annotate(
            manta = manta_row_ht[melt_mt.row_key].info.manta,
            # melt = melt_row_ht[melt_mt.row_key].info.melt,
            survindel2 = surv_row_ht[melt_mt.row_key].info.survindel2,
    ))
#melt_mt.describe()
melt_mt = melt_mt.annotate_entries(    
    manta = manta_mt[melt_mt.row_key, melt_mt.col_key].manta,
   # melt = melt_mt[melt_mt.row_key, melt_mt.col_key].melt,
    survindel2 = surv_mt[melt_mt.row_key, melt_mt.col_key].survindel2,
)
#melt_mt.describe()
melt_mt = melt_mt.checkpoint("SG10K_SV_MELT.n5487.m24674.discovery.complete_schema.mt", overwrite=True)
melt_mt.describe()



surv_mt = surv_mt.transmute_rows(
    info = surv_mt.info.annotate(
            manta = manta_row_ht[surv_mt.row_key].info.manta,
            melt = melt_row_ht[surv_mt.row_key].info.melt,
            # survindel2 = surv_row_ht[surv_mt.row_key].info.survindel2,
    ))
#surv_mt.describe()
surv_mt = surv_mt.annotate_entries(    
    manta = manta_mt[surv_mt.row_key, surv_mt.col_key].manta,
    melt = melt_mt[surv_mt.row_key, surv_mt.col_key].melt,
   # survindel2 = surv_mt[surv_mt.row_key, surv_mt.col_key].survindel2,
)
#surv_mt.describe()
surv_mt = surv_mt.checkpoint("SG10K_SV_SURVINDEL2.n5487.m32465.discovery.complete_schema.mt", overwrite=True)
surv_mt.describe()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {
#             ABHet: float64,
#             ABHom: float64,
#             ABHetMulti: array<float64>,
#             ABHomMulti: array<float64>,
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             CR: int32,
#             END: int32,
#             HOMSEQ: array<str>,
#             INV3: bool,
#             INV5: bool,
#             LEFT_SVINSSEQ: array<str>,
#             LOGF: float64,
#             MaxAAS: array<int32>,
#             MaxAASR: array<float64>,
#             MaxAltPP: int32,
#             MQ: int32,
#             MQsquared: int32,
#             NCLUSTERS: int32,
#             NGT: array<int32>,
#             NHet: int32,
#             NHomRef: int32,
#             NHomAlt: int32,
#             NUM_MERGED_SVS: int32,
#             OLD_VARIANT_ID: str,
#             ORSTART: int32,
#             OREND: int32,
#             QD: float64,
#             PASS_AC: array<int32>,
#             PASS_AN: int32,
#             PASS_ratio: float64,
#             PS: int32,
#             RefLen: int32,
#             RELATED_SV_ID: int32,
#             RIGHT_SVINSSEQ: array<str>,
#             SB: float64,
#             SBAlt: float64,
#             SBF: array<int32>,
#             SBF1: array<int32>,
#             SBF2: array<int32>,
#             SBR: array<int32>,
#             SBR1: array<int32>,
#             SBR2: array<int32>,
#             SEQ: str,
#             SeqDepth: int32,
#             SV_ID: int32,
#             SVINSSEQ: array<str>,
#             SVLEN: int32,
#             SVMODEL: str,
#             SVSIZE: int32,
#             SVTYPE: str,
#             VarType: str,
#             PASS_GT2_filter: str,
#             alleles: array<str>,
#             rsid: str
#         },
#         melt: struct {
#             ASSESS: int32,
#             TSD: str,
#             INTERNAL: array<str>,
#             SVTYPE: str,
#             SVLEN: int32,
#             MEINFO: array<str>,
#             DIFF: array<str>,
#             LP: int32,
#             RP: int32,
#             RA: float64,
#             PRIOR: str,
#             SR: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         survindel2: struct {
#             SVTYPE: str,
#             END: int32,
#             N_SAMPLES: int32,
#             N_SVS: int32,
#             GCF: float64,
#             SVSIZE: int32,
#             alleles: array<str>,
#             rsid: str
#         }
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {
#         GT: call,
#         FT: str,
#         AD: array<int32>,
#         MD: int32,
#         DP: int32,
#         RA: array<int32>,
#         PP: int32,
#         GQ: int32,
#         PL: array<int32>
#     }
#     'melt': struct {
#         GT: call,
#         GL: array<float64>,
#         DP: int32,
#         AD: int32,
#         PL: array<int32>
#     }
#     'survindel2': struct {
#         GT: call,
#         FT: str,
#         AR: int32,
#         SR: int32,
#         RR: int32,
#         RS: int32,
#         RE: int32,
#         CN: int32,
#         IL: int32,
#         WR: int32,
#         DFL: int32,
#         DDL: int32,
#         DDR: int32,
#         DFR: int32,
#         CID: int32,
#         OW: int32,
#         DHFC: float64,
#         DHBFC: float64,
#         DHFFC: float64,
#         DHSP: int32,
#         FS: str
#     }
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {
#             ABHet: float64,
#             ABHom: float64,
#             ABHetMulti: array<float64>,
#             ABHomMulti: array<float64>,
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             CR: int32,
#             END: int32,
#             HOMSEQ: array<str>,
#             INV3: bool,
#             INV5: bool,
#             LEFT_SVINSSEQ: array<str>,
#             LOGF: float64,
#             MaxAAS: array<int32>,
#             MaxAASR: array<float64>,
#             MaxAltPP: int32,
#             MQ: int32,
#             MQsquared: int32,
#             NCLUSTERS: int32,
#             NGT: array<int32>,
#             NHet: int32,
#             NHomRef: int32,
#             NHomAlt: int32,
#             NUM_MERGED_SVS: int32,
#             OLD_VARIANT_ID: str,
#             ORSTART: int32,
#             OREND: int32,
#             QD: float64,
#             PASS_AC: array<int32>,
#             PASS_AN: int32,
#             PASS_ratio: float64,
#             PS: int32,
#             RefLen: int32,
#             RELATED_SV_ID: int32,
#             RIGHT_SVINSSEQ: array<str>,
#             SB: float64,
#             SBAlt: float64,
#             SBF: array<int32>,
#             SBF1: array<int32>,
#             SBF2: array<int32>,
#             SBR: array<int32>,
#             SBR1: array<int32>,
#             SBR2: array<int32>,
#             SEQ: str,
#             SeqDepth: int32,
#             SV_ID: int32,
#             SVINSSEQ: array<str>,
#             SVLEN: int32,
#             SVMODEL: str,
#             SVSIZE: int32,
#             SVTYPE: str,
#             VarType: str,
#             PASS_GT2_filter: str,
#             alleles: array<str>,
#             rsid: str
#         },
#         melt: struct {
#             ASSESS: int32,
#             TSD: str,
#             INTERNAL: array<str>,
#             SVTYPE: str,
#             SVLEN: int32,
#             MEINFO: array<str>,
#             DIFF: array<str>,
#             LP: int32,
#             RP: int32,
#             RA: float64,
#             PRIOR: str,
#             SR: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         survindel2: struct {
#             SVTYPE: str,
#             END: int32,
#             N_SAMPLES: int32,
#             N_SVS: int32,
#             GCF: float64,
#             SVSIZE: int32,
#             alleles: array<str>,
#             rsid: str
#         }
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {
#         GT: call,
#         FT: str,
#         AD: array<int32>,
#         MD: int32,
#         DP: int32,
#         RA: array<int32>,
#         PP: int32,
#         GQ: int32,
#         PL: array<int32>
#     }
#     'melt': struct {
#         GT: call,
#         GL: array<float64>,
#         DP: int32,
#         AD: int32,
#         PL: array<int32>
#     }
#     'survindel2': struct {
#         GT: call,
#         FT: str,
#         AR: int32,
#         SR: int32,
#         RR: int32,
#         RS: int32,
#         RE: int32,
#         CN: int32,
#         IL: int32,
#         WR: int32,
#         DFL: int32,
#         DDL: int32,
#         DDR: int32,
#         DFR: int32,
#         CID: int32,
#         OW: int32,
#         DHFC: float64,
#         DHBFC: float64,
#         DHFFC: float64,
#         DHSP: int32,
#         FS: str
#     }
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {
#             ABHet: float64,
#             ABHom: float64,
#             ABHetMulti: array<float64>,
#             ABHomMulti: array<float64>,
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             CR: int32,
#             END: int32,
#             HOMSEQ: array<str>,
#             INV3: bool,
#             INV5: bool,
#             LEFT_SVINSSEQ: array<str>,
#             LOGF: float64,
#             MaxAAS: array<int32>,
#             MaxAASR: array<float64>,
#             MaxAltPP: int32,
#             MQ: int32,
#             MQsquared: int32,
#             NCLUSTERS: int32,
#             NGT: array<int32>,
#             NHet: int32,
#             NHomRef: int32,
#             NHomAlt: int32,
#             NUM_MERGED_SVS: int32,
#             OLD_VARIANT_ID: str,
#             ORSTART: int32,
#             OREND: int32,
#             QD: float64,
#             PASS_AC: array<int32>,
#             PASS_AN: int32,
#             PASS_ratio: float64,
#             PS: int32,
#             RefLen: int32,
#             RELATED_SV_ID: int32,
#             RIGHT_SVINSSEQ: array<str>,
#             SB: float64,
#             SBAlt: float64,
#             SBF: array<int32>,
#             SBF1: array<int32>,
#             SBF2: array<int32>,
#             SBR: array<int32>,
#             SBR1: array<int32>,
#             SBR2: array<int32>,
#             SEQ: str,
#             SeqDepth: int32,
#             SV_ID: int32,
#             SVINSSEQ: array<str>,
#             SVLEN: int32,
#             SVMODEL: str,
#             SVSIZE: int32,
#             SVTYPE: str,
#             VarType: str,
#             PASS_GT2_filter: str,
#             alleles: array<str>,
#             rsid: str
#         },
#         melt: struct {
#             ASSESS: int32,
#             TSD: str,
#             INTERNAL: array<str>,
#             SVTYPE: str,
#             SVLEN: int32,
#             MEINFO: array<str>,
#             DIFF: array<str>,
#             LP: int32,
#             RP: int32,
#             RA: float64,
#             PRIOR: str,
#             SR: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         survindel2: struct {
#             SVTYPE: str,
#             END: int32,
#             N_SAMPLES: int32,
#             N_SVS: int32,
#             GCF: float64,
#             SVSIZE: int32,
#             alleles: array<str>,
#             rsid: str
#         }
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {
#         GT: call,
#         FT: str,
#         AD: array<int32>,
#         MD: int32,
#         DP: int32,
#         RA: array<int32>,
#         PP: int32,
#         GQ: int32,
#         PL: array<int32>
#     }
#     'melt': struct {
#         GT: call,
#         GL: array<float64>,
#         DP: int32,
#         AD: int32,
#         PL: array<int32>
#     }
#     'survindel2': struct {
#         GT: call,
#         FT: str,
#         AR: int32,
#         SR: int32,
#         RR: int32,
#         RS: int32,
#         RE: int32,
#         CN: int32,
#         IL: int32,
#         WR: int32,
#         DFL: int32,
#         DDL: int32,
#         DDR: int32,
#         DFR: int32,
#         CID: int32,
#         OW: int32,
#         DHFC: float64,
#         DHBFC: float64,
#         DHFFC: float64,
#         DHSP: int32,
#         FS: str
#     }
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
# 2024-04-11 10:50:15 Hail: INFO: wrote matrix table with 36145 rows and 5487 columns in 53 partitions to SG10K_SV_MantaSVimmerGraphtyper.n5487.m36145.discovery.DEL-INS-only.complete_schema.mt
# 2024-04-11 10:50:54 Hail: INFO: wrote matrix table with 24674 rows and 5487 columns in 16 partitions to SG10K_SV_MELT.n5487.m24674.discovery.complete_schema.mt
# 2024-04-11 10:51:21 Hail: INFO: wrote matrix table with 32465 rows and 5487 columns in 22 partitions to SG10K_SV_SURVINDEL2.n5487.m32465.discovery.complete_schema.mt

# %%
mts = [manta_mt, melt_mt, surv_mt]
mt = mts.pop()
mt = mt.union_rows(*mts)
mt = mt.checkpoint("pre-merged.discovery.mt", overwrite=True)


mt.describe()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {
#             ABHet: float64,
#             ABHom: float64,
#             ABHetMulti: array<float64>,
#             ABHomMulti: array<float64>,
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             CR: int32,
#             END: int32,
#             HOMSEQ: array<str>,
#             INV3: bool,
#             INV5: bool,
#             LEFT_SVINSSEQ: array<str>,
#             LOGF: float64,
#             MaxAAS: array<int32>,
#             MaxAASR: array<float64>,
#             MaxAltPP: int32,
#             MQ: int32,
#             MQsquared: int32,
#             NCLUSTERS: int32,
#             NGT: array<int32>,
#             NHet: int32,
#             NHomRef: int32,
#             NHomAlt: int32,
#             NUM_MERGED_SVS: int32,
#             OLD_VARIANT_ID: str,
#             ORSTART: int32,
#             OREND: int32,
#             QD: float64,
#             PASS_AC: array<int32>,
#             PASS_AN: int32,
#             PASS_ratio: float64,
#             PS: int32,
#             RefLen: int32,
#             RELATED_SV_ID: int32,
#             RIGHT_SVINSSEQ: array<str>,
#             SB: float64,
#             SBAlt: float64,
#             SBF: array<int32>,
#             SBF1: array<int32>,
#             SBF2: array<int32>,
#             SBR: array<int32>,
#             SBR1: array<int32>,
#             SBR2: array<int32>,
#             SEQ: str,
#             SeqDepth: int32,
#             SV_ID: int32,
#             SVINSSEQ: array<str>,
#             SVLEN: int32,
#             SVMODEL: str,
#             SVSIZE: int32,
#             SVTYPE: str,
#             VarType: str,
#             PASS_GT2_filter: str,
#             alleles: array<str>,
#             rsid: str
#         },
#         melt: struct {
#             ASSESS: int32,
#             TSD: str,
#             INTERNAL: array<str>,
#             SVTYPE: str,
#             SVLEN: int32,
#             MEINFO: array<str>,
#             DIFF: array<str>,
#             LP: int32,
#             RP: int32,
#             RA: float64,
#             PRIOR: str,
#             SR: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         survindel2: struct {
#             SVTYPE: str,
#             END: int32,
#             N_SAMPLES: int32,
#             N_SVS: int32,
#             GCF: float64,
#             SVSIZE: int32,
#             alleles: array<str>,
#             rsid: str
#         }
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {
#         GT: call,
#         FT: str,
#         AD: array<int32>,
#         MD: int32,
#         DP: int32,
#         RA: array<int32>,
#         PP: int32,
#         GQ: int32,
#         PL: array<int32>
#     }
#     'melt': struct {
#         GT: call,
#         GL: array<float64>,
#         DP: int32,
#         AD: int32,
#         PL: array<int32>
#     }
#     'survindel2': struct {
#         GT: call,
#         FT: str,
#         AR: int32,
#         SR: int32,
#         RR: int32,
#         RS: int32,
#         RE: int32,
#         CN: int32,
#         IL: int32,
#         WR: int32,
#         DFL: int32,
#         DDL: int32,
#         DDR: int32,
#         DFR: int32,
#         CID: int32,
#         OW: int32,
#         DHFC: float64,
#         DHBFC: float64,
#         DHFFC: float64,
#         DHSP: int32,
#         FS: str
#     }
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
# 2024-04-11 10:51:52 Hail: INFO: wrote matrix table with 93284 rows and 5487 columns in 91 partitions to pre-merged.discovery.mt

# %%
mt = mt.annotate_rows(
    info = mt.info.annotate(
        SVTYPE = hl.coalesce(
            mt.info.manta.SVTYPE,
            hl.or_missing(hl.is_defined(mt.info.melt.SVTYPE), "INS"), #mt.info.melt.SVTYPE,
            mt.info.survindel2.SVTYPE
        ),
        SVSIZE = hl.coalesce(
            hl.if_else(mt.info.manta.SVSIZE > 0, mt.info.manta.SVSIZE, hl.missing(hl.tint32)),
            hl.if_else(mt.info.melt.SVLEN > 0, mt.info.melt.SVLEN, hl.missing(hl.tint32)),
            hl.if_else(mt.info.survindel2.SVSIZE > 0, mt.info.survindel2.SVSIZE, hl.missing(hl.tint32)),
        ),
    )
)

mt = mt.annotate_rows(
    rsid = "SG10K_SV_" 
               + mt.info.SVTYPE  + "_" 
               + mt.locus.contig + "_"
               + hl.str(mt.locus.position) + "_" 
               +  hl.or_else(hl.str(mt.info.SVSIZE), "UNDEF")
)
    
    
    
mt = mt.annotate_entries(
    GT = hl.coalesce(mt.manta.GT,mt.melt.GT,mt.survindel2.GT),
    DP = hl.coalesce(mt.manta.DP,mt.melt.DP),
#    AD = hl.coalesce(mt.manta.AD,mt.melt.AD),
    PL = hl.coalesce(mt.manta.PL,mt.melt.PL),
)
 
mt.describe()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         manta: struct {
#             ABHet: float64,
#             ABHom: float64,
#             ABHetMulti: array<float64>,
#             ABHomMulti: array<float64>,
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             CR: int32,
#             END: int32,
#             HOMSEQ: array<str>,
#             INV3: bool,
#             INV5: bool,
#             LEFT_SVINSSEQ: array<str>,
#             LOGF: float64,
#             MaxAAS: array<int32>,
#             MaxAASR: array<float64>,
#             MaxAltPP: int32,
#             MQ: int32,
#             MQsquared: int32,
#             NCLUSTERS: int32,
#             NGT: array<int32>,
#             NHet: int32,
#             NHomRef: int32,
#             NHomAlt: int32,
#             NUM_MERGED_SVS: int32,
#             OLD_VARIANT_ID: str,
#             ORSTART: int32,
#             OREND: int32,
#             QD: float64,
#             PASS_AC: array<int32>,
#             PASS_AN: int32,
#             PASS_ratio: float64,
#             PS: int32,
#             RefLen: int32,
#             RELATED_SV_ID: int32,
#             RIGHT_SVINSSEQ: array<str>,
#             SB: float64,
#             SBAlt: float64,
#             SBF: array<int32>,
#             SBF1: array<int32>,
#             SBF2: array<int32>,
#             SBR: array<int32>,
#             SBR1: array<int32>,
#             SBR2: array<int32>,
#             SEQ: str,
#             SeqDepth: int32,
#             SV_ID: int32,
#             SVINSSEQ: array<str>,
#             SVLEN: int32,
#             SVMODEL: str,
#             SVSIZE: int32,
#             SVTYPE: str,
#             VarType: str,
#             PASS_GT2_filter: str,
#             alleles: array<str>,
#             rsid: str
#         },
#         melt: struct {
#             ASSESS: int32,
#             TSD: str,
#             INTERNAL: array<str>,
#             SVTYPE: str,
#             SVLEN: int32,
#             MEINFO: array<str>,
#             DIFF: array<str>,
#             LP: int32,
#             RP: int32,
#             RA: float64,
#             PRIOR: str,
#             SR: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         survindel2: struct {
#             SVTYPE: str,
#             END: int32,
#             N_SAMPLES: int32,
#             N_SVS: int32,
#             GCF: float64,
#             SVSIZE: int32,
#             alleles: array<str>,
#             rsid: str
#         },
#         SVTYPE: str,
#         SVSIZE: int32
#     }
# ----------------------------------------
# Entry fields:
#     'manta': struct {
#         GT: call,
#         FT: str,
#         AD: array<int32>,
#         MD: int32,
#         DP: int32,
#         RA: array<int32>,
#         PP: int32,
#         GQ: int32,
#         PL: array<int32>
#     }
#     'melt': struct {
#         GT: call,
#         GL: array<float64>,
#         DP: int32,
#         AD: int32,
#         PL: array<int32>
#     }
#     'survindel2': struct {
#         GT: call,
#         FT: str,
#         AR: int32,
#         SR: int32,
#         RR: int32,
#         RS: int32,
#         RE: int32,
#         CN: int32,
#         IL: int32,
#         WR: int32,
#         DFL: int32,
#         DDL: int32,
#         DDR: int32,
#         DFR: int32,
#         CID: int32,
#         OW: int32,
#         DHFC: float64,
#         DHBFC: float64,
#         DHFFC: float64,
#         DHSP: int32,
#         FS: str
#     }
#     'GT': call
#     'DP': int32
#     'PL': array<int32>
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %%
## write the resulting mt
release14_mt_uri =   "SG10K-SV-Release-1.4.mt"
mt.write(release14_mt_uri, overwrite=True)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 2024-04-11 11:17:33 Hail: INFO: wrote matrix table with 93284 rows and 5487 columns in 91 partitions to SG10K-SV-Release-1.4.mt
